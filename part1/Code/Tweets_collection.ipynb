# %%
# 5000 tweets on trump_or_hillary
library(rtweet)

twitter_token <- create_token(app = "MapReduce_DIC",
  consumer_key = "YIOCdZHjofrpDWAobTBFJF9HL",
  consumer_secret = "qsuVR4MF7cdAlifOogjoEsAU5oU7Ir3EZFpYrGgDNizEy7iink")

tweets <- search_tweets(q = "Trump OR Hilary Clinton", n = 5000, token = twitter_token, geocode = lookup_coords("usa"), include_rts = FALSE)
#tweets
save_as_csv(tweets,"trump_hillary.csv")



# 5000 tweets on Political party
library(rtweet)

twitter_token <- create_token(app = "MapReduce_DIC",
  consumer_key = "YIOCdZHjofrpDWAobTBFJF9HL",
  consumer_secret = "qsuVR4MF7cdAlifOogjoEsAU5oU7Ir3EZFpYrGgDNizEy7iink")

tweets <- search_tweets(q = "Political Party", n = 5000, token = twitter_token, geocode = lookup_coords("usa"), include_rts = FALSE)
#tweets
save_as_csv(tweets,"politics.csv")


# 5000 tweets on Government
library(rtweet)

twitter_token <- create_token(app = "MapReduce_DIC",
  consumer_key = "YIOCdZHjofrpDWAobTBFJF9HL",
  consumer_secret = "qsuVR4MF7cdAlifOogjoEsAU5oU7Ir3EZFpYrGgDNizEy7iink")

tweets <- search_tweets(q = "Government", n = 5000, token = twitter_token, geocode = lookup_coords("usa"), include_rts = FALSE)
#tweets
save_as_csv(tweets,"government.csv")


# 5000 tweets on Elections
library(rtweet)

twitter_token <- create_token(app = "MapReduce_DIC",
  consumer_key = "YIOCdZHjofrpDWAobTBFJF9HL",
  consumer_secret = "qsuVR4MF7cdAlifOogjoEsAU5oU7Ir3EZFpYrGgDNizEy7iink")

tweets <- search_tweets(q = "Elections", n = 5000, token = twitter_token, geocode = lookup_coords("usa"), include_rts = FALSE)
#tweets
save_as_csv(tweets,"elections.csv")


# 5000 tweets on Vote
library(rtweet)

twitter_token <- create_token(app = "MapReduce_DIC",
  consumer_key = "YIOCdZHjofrpDWAobTBFJF9HL",
  consumer_secret = "qsuVR4MF7cdAlifOogjoEsAU5oU7Ir3EZFpYrGgDNizEy7iink")

tweets <- search_tweets(q = "Vote", n = 5000, token = twitter_token, geocode = lookup_coords("usa"), include_rts = FALSE)
#tweets
save_as_csv(tweets,"Vote.csv")
